# %% [markdown]
# # Explore Transformers

# %% [markdown]
# We wil use the `transformers` package from `HuggingFace`, that provides a unified interface to a variety of Transormer nodels.

# %%
from transformers import AutoModel, AutoTokenizer
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# Pretrained models can be downloaded directly from the HuggingFace repository.
#
# We need also the Tokenizer for a given model, since each model may do it differently.

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# %% [markdown]
# Here we get the base BERT model `uncased`, i.i. where toknes are all lowercased.

# %%
model = AutoModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
wps_ids = tokenizer.encode("Hypatia was a mathematician")
wps_ids
# Out:
# [101, 1044, 22571, 10450, 2050, 2001, 1037, 13235, 102]

# %%
wordpieces = tokenizer.convert_ids_to_tokens(wps_ids)

# %% [markdown]
# See what they are:

# %%
wordpieces
# Out:
# ['[CLS]', 'h', '##yp', '##ati', '##a', 'was', 'a', 'mathematician', '[SEP]']

# %% [markdown]
# Convert to tensor

# %%
import torch
wps_tensor = torch.tensor([wps_ids])

# %%
outputs = model(wps_tensor, output_hidden_states=True, output_attentions=True)

# %%
last_hidden_state = outputs.last_hidden_state
pooler_output = outputs.pooler_output
hidden_states = outputs.hidden_states
attentions = outputs.attentions

# %% [markdown]
# `last_hidden_state` is the sequence of hidden-states at the output of the last layer of the model.
#
# shape: (batch_size, sequence_length, hidden_size)

# %%
last_hidden_state[0]
# Out:
# tensor([[-0.1904, -0.2317, -0.4896,  ..., -0.4366,  0.5167,  0.5166],
#         [ 0.7274,  0.4021, -0.4051,  ..., -0.9010,  1.4341,  0.2526],
#         [-0.2553, -0.1450, -0.4257,  ..., -0.8199,  1.1043,  0.2408],
#         ...,
#         [ 0.1278,  0.1691, -0.8889,  ..., -0.6259,  0.1597,  0.8265],
#         [-0.8941, -0.1419, -0.6008,  ..., -0.1861,  0.8240,  0.4556],
#         [ 0.7600,  0.0256, -0.5482,  ...,  0.2768, -0.5651, -0.2150]],
#        grad_fn=<SelectBackward>)

# %%
last_hidden_state[0].shape
# Out:
# torch.Size([9, 768])

# %% [markdown]
# `pooler_output` Last layer hidden-state of the first token of the sequence (**classification token**) further processed by a Linear layer and a Tanh activation function. The Linear layer weights are trained from the next sentence prediction (classification) objective during pretraining.
#
# shape: `(batch_size, hidden_size)`

# %%
len(pooler_output[0])
# Out:
# 768

# %% [markdown]
# `hidden_states` is a Tuple of `torch.FloatTensor` (one for the output of the embeddings + one for the output of each layer.
#
# shape of each layer: `(batch_size, sequence_length, hidden_size)`

# %%
len(hidden_states)
# Out:
# 13

# %% [markdown]
# Look at the last layer

# %%
hidden_states[-1][0]
# Out:
# tensor([[-0.1904, -0.2317, -0.4896,  ..., -0.4366,  0.5167,  0.5166],
#         [ 0.7274,  0.4021, -0.4051,  ..., -0.9010,  1.4341,  0.2526],
#         [-0.2553, -0.1450, -0.4257,  ..., -0.8199,  1.1043,  0.2408],
#         ...,
#         [ 0.1278,  0.1691, -0.8889,  ..., -0.6259,  0.1597,  0.8265],
#         [-0.8941, -0.1419, -0.6008,  ..., -0.1861,  0.8240,  0.4556],
#         [ 0.7600,  0.0256, -0.5482,  ...,  0.2768, -0.5651, -0.2150]],
#        grad_fn=<SelectBackward>)

# %% [markdown]
# Look at the one for the first wordpiece (skipping (CLS]):

# %%
hidden_states[-1][0][1]
# Out:
# tensor([ 7.2743e-01,  4.0206e-01, -4.0513e-01,  3.0209e-01,  6.8818e-02,
#          1.0866e-01, -1.2657e-01,  1.4593e+00, -4.8246e-01,  2.5372e-01,
#          1.5767e-01, -6.2645e-01,  5.0674e-02,  2.6216e-01, -1.9618e-01,
#         -3.6497e-01, -4.1162e-01, -3.6958e-01, -3.2668e-01, -6.8400e-02,
#          6.4011e-01,  1.2157e-01, -5.9686e-02,  3.3221e-01,  1.6070e-01,
#          1.2944e-01,  7.5560e-02,  6.3244e-01, -3.3727e-01,  1.7607e-01,
#          1.6163e-02, -9.3616e-01,  2.2640e-02, -7.7795e-01,  1.1385e-01,
#          6.0136e-01, -8.5157e-01,  2.3465e-01,  5.7237e-01,  1.1199e-01,
#         -5.7691e-01, -4.6522e-01,  2.8443e-01, -2.1060e-01, -2.7226e-02,
#          1.4974e-01, -5.0491e-01, -9.0769e-01,  3.3629e-02, -3.4374e-01,
#         -7.1083e-01,  7.9934e-02, -1.1527e+00,  6.2862e-01,  5.6249e-01,
#          1.5110e+00, -5.6712e-01, -6.9483e-01, -3.1478e-01,  7.7170e-02,
#          1.3527e-01, -2.1106e-01, -3.6059e-01,  4.1817e-01,  8.0597e-01,
#          5.8128e-01, -5.5423e-01,  6.9554e-01,  7.5980e-02,  9.9255e-01,
#         -4.8275e-01, -2.1801e-01, -3.8283e-01,  1.4025e+00,  4.5281e-02,
#         -7.8584e-01,  4.1643e-01,  1.6864e-01,  9.2174e-01, -6.8364e-01,
#         -1.2755e-01,  7.3576e-01,  2.7586e-01,  4.0729e-01, -1.2347e+00,
#          1.4391e-01,  4.0308e-01,  6.3100e-01, -3.3853e-02, -2.8892e-01,
#         -5.8268e-01,  8.5998e-02,  1.4163e-01, -1.9946e-02, -6.2845e-01,
#         -5.9053e-01, -1.0081e+00,  5.4810e-01, -3.9688e-01, -2.6587e-01,
#         -1.0049e-01, -4.7405e-01, -1.8931e+00, -4.6906e-01, -1.9185e-01,
#         -1.8826e-01, -3.3125e-01, -6.1242e-01, -1.6612e-01, -1.9958e-01,
#          2.9913e-01,  6.8628e-02, -6.1213e-01,  7.0561e-01,  4.6909e-01,
#          3.4952e-01, -8.3635e-01, -1.0213e-01, -7.7086e-01, -1.4019e-01,
#          2.3260e-01,  4.9600e-01,  1.1662e+00,  7.7412e-01, -2.3599e-01,
#         -2.7604e-01,  3.0782e-01,  5.2120e-01,  7.1895e-02,  1.8803e-01,
#         -6.2416e-01, -1.8370e-01, -4.8610e-01, -9.2631e-02,  2.9696e-01,
#          3.7801e-01, -1.6277e-01,  2.1373e-02, -1.0774e+00, -2.4607e-01,
#          1.3681e+00,  3.5112e-01, -3.3070e-01, -6.1000e-01, -9.8325e-01,
#         -1.3962e-01,  4.2961e-01,  9.9965e-01,  2.2698e-01, -7.2057e-03,
#         -2.2282e-01,  1.3428e-01, -2.1202e-02, -1.1113e-01,  1.7215e-01,
#         -7.4673e-01, -1.6588e-02,  3.8160e-01, -9.0036e-02,  3.0969e-01,
#          5.8421e-01, -3.0685e-01, -9.6904e-01,  2.6731e-01,  3.7267e-01,
#          4.6109e-01,  4.2858e-01, -8.7917e-01,  8.8057e-01, -5.7032e-01,
#         -2.4018e-01, -3.1232e-01,  2.3760e-01, -3.4991e-01, -4.5252e-01,
#         -8.3759e-01,  1.2084e+00,  2.2320e-01,  4.0133e-01,  1.8379e-01,
#         -1.3163e-01,  4.2776e-01,  6.4261e-01, -6.9490e-02, -2.9465e-01,
#         -6.9214e-01,  1.1980e+00,  1.2063e-01, -4.9303e-01, -8.1096e-01,
#         -1.8556e-02,  4.0167e-01, -9.5232e-01, -4.8000e-01,  6.1277e-01,
#         -1.1973e-01,  1.5146e-01, -8.3946e-01,  6.7465e-01, -2.0671e-01,
#         -2.4258e-01, -8.5614e-01, -1.8526e-01, -7.1115e-01, -3.6475e-03,
#          5.5132e-01, -9.0005e-01,  3.2435e-01, -4.3925e-01,  2.4102e-01,
#          2.5878e-02, -6.2236e-03, -1.1924e-01, -4.5978e-01, -1.8622e-02,
#          8.3942e-01,  4.0267e-01,  1.8851e-01,  3.1137e-01, -2.3095e-01,
#          3.7353e-02, -4.3784e-01,  2.8761e-01, -1.0749e+00, -4.9226e-01,
#          1.7838e+00,  7.4489e-01, -3.5547e-01,  2.4269e-01, -2.3893e-01,
#         -1.6877e-01,  2.8618e-02,  6.1095e-01, -1.9881e-01, -1.0158e-01,
#         -9.0158e-01, -7.2977e-01, -1.3768e-01,  2.8701e-01, -7.7791e-01,
#         -8.3260e-01, -3.1163e-01, -3.8020e-01,  2.6541e-02,  5.0177e-01,
#         -2.0446e-01,  1.9540e-01,  1.6814e-01, -1.9130e-01, -4.7372e-01,
#         -8.9195e-01,  4.2935e-02, -5.3114e-03, -1.3636e+00,  2.3217e-01,
#          7.2079e-01,  1.2273e+00,  3.4337e-01, -1.5004e-01, -4.8660e-01,
#         -1.7220e-01,  9.3230e-01,  3.6480e-01,  5.0585e-01,  8.3422e-02,
#         -8.8595e-01,  6.8731e-01,  9.8791e-01,  2.2073e-01, -1.1975e-01,
#          1.9912e-01, -6.8513e-01,  2.6147e-01,  9.9910e-01, -6.4146e-01,
#         -2.6082e-01,  7.9048e-02,  1.0317e-01,  4.1822e-01, -7.9574e-02,
#         -4.3161e-01,  7.4354e-01, -8.6756e-01, -5.5856e-01, -9.3062e-01,
#         -3.7913e-01,  4.2049e-01, -4.1398e-01, -2.4176e-02, -6.0724e-01,
#         -8.0972e-02,  2.1033e-01, -6.1142e-01, -1.6561e-01,  6.7271e-01,
#          4.6674e-01,  2.1672e-01,  4.1460e-01, -1.5364e-01, -1.0382e+00,
#         -1.1246e+00,  2.3433e-01, -2.5679e-01,  2.0616e-01,  3.8070e-01,
#          2.5403e-01,  3.4969e-01, -3.1987e-01, -2.9691e+00,  2.3101e-01,
#         -6.7283e-01, -5.4666e-01,  1.7360e-01,  3.9860e-02, -6.3859e-02,
#          4.1849e-01, -6.9959e-01,  1.0438e-01,  9.9739e-02, -7.5484e-01,
#         -3.1115e-01, -5.6255e-01,  1.5100e+00,  1.8963e-01,  4.8475e-01,
#         -1.0701e-01,  1.0385e-01,  3.5896e-02, -8.3007e-01, -1.0463e-01,
#         -5.5390e-01,  4.3756e-01, -2.5705e-01,  5.5374e-02, -4.4255e-01,
#          5.2890e-02, -1.3557e+00, -3.1065e-01,  3.6901e-01, -9.3734e-01,
#          1.0832e-01,  1.7326e-01,  5.1894e-01,  1.0086e-01,  1.0893e-01,
#          8.1622e-02, -9.8364e-02, -5.3775e-01, -2.0722e-01, -1.0282e+00,
#          2.0061e-01,  2.5595e-01,  7.9307e-01, -3.4575e-01,  1.2999e-01,
#         -4.3199e-01, -1.8647e-01,  6.8284e-01,  3.6487e-01,  1.1595e-01,
#          3.6720e-01, -5.9270e-01,  1.3900e-01,  2.4557e-02,  2.4543e-01,
#          1.2632e+00,  2.9184e-01, -1.1786e+00,  8.1821e-01,  2.8531e-01,
#         -5.1141e-01, -3.4210e-01,  3.5571e-01, -9.1605e-01, -9.4080e-01,
#         -3.1196e-01, -4.3061e-01, -8.3578e-01, -7.6602e-01, -5.8282e-02,
#         -9.2556e-02, -7.4723e-01, -2.7442e-01, -5.6985e-01,  4.8438e-01,
#          9.0289e-02, -5.5351e-01, -1.2239e-01, -4.4113e-01, -8.1435e-01,
#          9.8553e-01,  6.1997e-01,  6.0395e-02,  2.6776e-02, -4.6047e-01,
#          1.4566e-01, -4.5306e-01, -2.1135e-01, -1.7251e-01,  9.8528e-01,
#         -1.0333e-01,  3.3437e-01, -3.9591e-01, -3.4515e-02, -1.2886e+00,
#          4.2439e-02,  5.0678e-01,  7.6496e-02,  5.1114e-02,  3.4561e-01,
#         -2.8064e-01,  1.5978e-01, -4.9189e-02, -7.0310e-02, -1.5020e+00,
#         -1.2099e-01, -9.1708e-01, -5.2389e-01,  1.1248e+00,  1.8567e-01,
#          1.0833e+00,  5.3456e-01, -4.8479e-01, -2.4124e-01,  6.9940e-02,
#          1.4617e+00,  3.3113e-01,  5.3700e-02, -5.4843e-02,  1.4485e+00,
#         -3.2990e-01, -1.4909e+00, -4.6153e-01,  2.7380e-01, -3.3466e-01,
#          2.2895e-01, -1.1729e+00,  5.0259e-01,  1.4658e-01, -7.0595e-01,
#          7.7065e-01,  7.9240e-01, -2.8373e-01, -2.5312e-01, -4.4215e-01,
#         -7.0964e-01, -9.4213e-02,  1.0099e+00, -5.4506e-01, -2.0809e-01,
#         -9.1059e-01,  9.7939e-01,  3.5996e-01,  2.4976e-01, -3.1419e-01,
#         -4.1121e-01,  4.3053e-01,  1.4783e-01, -3.2989e-01,  1.4325e-01,
#          1.1523e+00, -1.0277e+00, -7.4653e-01, -5.8345e-01,  1.0004e+00,
#         -1.2092e-01, -4.0616e-01, -1.1248e-01, -7.7050e-01,  4.8411e-01,
#          9.3266e-01,  1.1394e-01, -1.1542e+00,  3.6297e-01, -4.9360e-01,
#         -4.4980e-02,  3.5846e-01, -3.2253e-01,  1.9746e-05,  8.8824e-01,
#         -6.4144e-01, -7.0585e-01, -6.4791e-02,  8.5179e-01,  3.3750e-01,
#         -2.1619e-01, -5.5390e-01,  4.6623e-01,  4.8319e-01, -8.9505e-01,
#          7.2484e-02, -4.2829e-01,  3.0099e-01,  5.3785e-01,  2.7406e-01,
#         -1.3749e+00,  3.3414e-01, -5.5279e-01, -4.7734e-01,  1.0213e+00,
#         -1.1371e+00, -3.9600e-02, -1.1496e+00, -5.8724e-01,  1.1300e+00,
#         -5.6682e-01,  2.8814e-01,  2.5733e-01,  6.5010e-02, -3.1399e-01,
#          4.3974e-02, -2.4747e-02, -5.6377e-01,  1.4256e-01, -1.2766e-02,
#          2.9329e-01,  7.1629e-01, -2.9173e-02, -1.8261e+00,  6.8554e-01,
#         -8.9684e-01, -2.1874e-01, -6.4159e-01,  1.7009e-01, -3.6132e-01,
#         -9.2183e-02, -5.5367e-01,  6.1259e-03, -7.0995e-01, -1.1422e+00,
#         -1.3315e-01,  3.0154e-01, -1.3614e-01,  1.8150e-01,  1.0259e-01,
#          1.1311e+00, -5.1214e-01, -6.6474e-01,  6.3628e-03, -6.9688e-01,
#          9.2536e-01, -9.3113e-01,  1.3348e+00, -9.3440e-01,  1.2338e-01,
#         -1.7222e-01, -6.2596e-01, -1.3298e-01,  6.9041e-01,  8.0617e-02,
#         -6.1777e-01, -8.2504e-01, -5.3868e-02, -1.7862e-01,  1.3577e+00,
#          5.2907e-01,  5.5913e-01, -2.7583e-01,  3.9233e-01, -3.3181e-01,
#         -9.4489e-01, -2.7375e-01, -4.7566e-01, -2.6878e-01, -4.2071e-01,
#         -4.1113e-01,  3.9898e-01,  6.5581e-02,  8.1090e-01, -7.0757e-02,
#         -7.9821e-02,  2.0362e-02, -2.4606e-01,  5.0155e-01, -3.2792e-01,
#          2.1690e-01,  1.0284e-03, -2.0900e-03,  1.3197e-02,  2.6211e-01,
#          3.6752e-01,  4.6406e-01,  1.5686e-01,  4.9500e-02, -2.8449e-01,
#          3.5957e-02,  1.5041e-01, -4.8333e-01, -4.3719e-01,  1.1140e+00,
#         -1.1263e-01,  1.4681e-01,  1.2320e-01,  1.8379e-01, -2.4469e-01,
#          4.8032e-01,  3.5928e-01, -2.0359e-02,  8.1803e-01, -2.6609e-02,
#          3.8127e-01, -1.2339e-01,  1.6743e-01,  5.9628e-01, -7.5623e-01,
#          2.1157e-01, -5.1859e-01,  4.9542e-01, -4.9499e-01,  1.7396e-01,
#          4.9789e-01,  7.8130e-01, -9.6517e-01,  5.5666e-01, -9.6012e-02,
#          3.3832e-01,  3.3951e-01,  9.0933e-01,  2.8395e-02, -1.3653e+00,
#          5.3384e-01, -3.5062e-01,  4.5439e-02, -4.0948e-01,  9.6071e-02,
#         -1.6613e-01,  1.6994e-01, -7.0781e-02, -2.0314e-01,  4.1327e-02,
#          3.7072e-02,  9.5077e-02,  4.5698e-01,  2.7775e-01, -1.1457e+00,
#          1.0608e+00,  1.0498e-01,  8.6141e-01, -5.9824e-01,  2.5184e-01,
#          7.8042e-01,  3.6360e-01, -1.5628e-01, -6.1934e-01,  3.1691e-01,
#          1.6984e-01,  1.3734e-02,  3.8479e-01,  5.3547e-01,  6.3367e-01,
#          2.6903e-01,  8.7115e-01,  3.4786e-02,  8.4663e-01,  1.1807e-01,
#         -7.9028e-01,  4.8253e-01,  1.9129e-01,  5.4820e-01,  7.7116e-01,
#          4.9003e-03,  3.0745e-01,  9.8730e-01,  1.9804e-01,  1.1226e+00,
#          8.9191e-01, -1.0427e-01,  3.5661e-01,  1.0392e+00, -9.2803e-01,
#          7.9468e-01, -1.3544e+00, -6.7147e-01,  3.4532e-01, -4.3690e-01,
#         -6.6332e-02,  7.9648e-01, -5.8145e-01, -5.8163e-01,  1.6700e-01,
#         -5.2098e-01,  3.0089e-01,  1.2501e-01, -3.2488e-03,  7.8034e-02,
#          2.9126e-01,  1.4291e-01, -1.0612e+00,  5.8493e-03, -1.3276e-01,
#         -1.7676e-01,  5.1139e-01, -2.7883e-01, -6.0529e-01,  4.3469e-01,
#          6.3520e-01,  1.2425e-01, -4.3788e-01, -6.3203e-02,  2.6420e-01,
#          9.1662e-01,  7.1863e-02, -7.8673e-01,  9.2102e-01,  2.2425e-01,
#          4.9286e-01, -7.3504e-02, -9.7948e-02, -4.0651e-01, -3.0214e-01,
#          4.3099e-02,  1.4280e-01,  2.6437e-01,  1.8103e-01, -3.1960e-01,
#          1.4436e-01, -1.5241e+00, -3.2580e-01,  5.6867e-01,  1.2455e+00,
#         -7.5826e-01,  5.7765e-01, -2.7868e-01,  2.3825e-01,  5.6873e-01,
#          1.1788e-01,  6.3347e-01,  1.1814e+00,  4.6566e-02, -3.4195e-01,
#         -3.3006e-01,  3.1498e-01, -4.9958e-01, -3.9427e-02,  2.2176e-01,
#          8.5819e-01, -8.1927e-01,  9.0878e-01,  3.4346e-01,  1.8393e-01,
#          2.9055e-01, -1.1213e+00, -7.4113e-02,  4.3353e-01, -3.5747e-01,
#         -4.5059e-01, -6.1498e-01, -7.8820e-01,  3.1224e-01,  2.1629e-01,
#          2.7522e-01, -9.5145e-02,  1.1518e+00,  5.8640e-01, -1.8116e-01,
#          9.1419e-01, -4.5228e-01, -1.5815e-01,  5.3007e-01, -3.4676e-03,
#          1.2989e+00,  4.1521e-01, -2.1484e-01, -1.3078e-01, -5.2203e-02,
#         -9.0098e-01,  1.4341e+00,  2.5259e-01], grad_fn=<SelectBackward>)

# %% [markdown]
# `attentions` Attentions weights after the attention softmax, used to compute the weighted average in the self-attention heads.
#
# shape: `(batch_size, num_heads, sequence_length, sequence_length)`

# %%
attentions[0].shape
# Out:
# torch.Size([1, 12, 9, 9])

# %% [markdown]
# Look at the single head:

# %%
attentions[0][0].shape
# Out:
# torch.Size([12, 9, 9])

# %% [markdown]
# Attentions for last layer

# %%
attentions[0][0][-1].shape
# Out:
# torch.Size([9, 9])

# %%
attentions[0][0][-1]
# Out:
# tensor([[8.9986e-01, 8.9166e-03, 3.4554e-03, 8.5585e-04, 2.9731e-03, 4.7226e-03,
#          3.5215e-02, 4.7056e-03, 3.9298e-02],
#         [1.2391e-01, 8.4317e-02, 3.2262e-01, 1.5241e-01, 4.7131e-02, 6.6522e-02,
#          5.5258e-02, 2.4437e-02, 1.2340e-01],
#         [2.3238e-03, 9.2049e-01, 2.0366e-03, 4.4564e-02, 5.7512e-03, 9.3530e-04,
#          1.4572e-02, 6.2075e-03, 3.1225e-03],
#         [2.4987e-01, 2.4486e-02, 2.8669e-01, 1.5228e-02, 2.8864e-02, 4.3187e-02,
#          5.5294e-02, 8.2267e-02, 2.1411e-01],
#         [7.1093e-02, 8.7373e-02, 4.1576e-01, 2.2153e-01, 8.9381e-03, 1.1020e-02,
#          3.6452e-02, 2.6599e-02, 1.2124e-01],
#         [2.0167e-01, 1.2511e-01, 1.4100e-01, 4.7089e-02, 4.2112e-02, 1.3234e-01,
#          9.5376e-02, 1.6339e-01, 5.1919e-02],
#         [2.1234e-01, 1.6746e-02, 1.0519e-01, 1.7828e-02, 6.2450e-02, 2.4318e-01,
#          5.8937e-02, 1.3822e-01, 1.4510e-01],
#         [2.9630e-01, 3.4920e-02, 5.3029e-02, 1.3975e-01, 1.0845e-02, 1.8033e-02,
#          9.1013e-02, 8.4441e-02, 2.7167e-01],
#         [6.3046e-01, 1.6802e-02, 1.3285e-02, 3.1083e-03, 9.7104e-03, 1.9965e-02,
#          5.7033e-02, 8.0568e-02, 1.6907e-01]], grad_fn=<SelectBackward>)

# %% [markdown]
# # Visualize model

# %%
from bertviz import model_view

# %%
def show_model_view(model, tokenizer, sentence_a, sentence_b=None, hide_delimiter_attn=False, display_mode="dark"):
    """Visualize the attention weights produced by model on sentence_a.
    If sentence_b is provided, the two sentences are concatenated with separator token in between.
    """
    # return_tensors='pt' means to return values as PyTorch tensors.
    inputs = tokenizer.encode_plus(sentence_a, sentence_b, return_tensors='pt', add_special_tokens=True)
    input_ids = inputs['input_ids']
    if sentence_b:
        token_type_ids = inputs['token_type_ids'] # 0 for fiest sentence, 1 for second
        attention = model(input_ids, token_type_ids=token_type_ids, output_attentions=True).attentions
        sentence_b_start = token_type_ids[0].tolist().index(1)
    else:
        attention = model(input_ids).attentions
        sentence_b_start = None
    input_id_list = input_ids[0].tolist() # Batch index 0
    tokens = tokenizer.convert_ids_to_tokens(input_id_list)  
    if hide_delimiter_attn:
        for i, t in enumerate(tokens):
            if t in ("[SEP]", "[CLS]"):
                for layer_attn in attention:
                    layer_attn[0, :, i, :] = 0
                    layer_attn[0, :, :, i] = 0
    model_view(attention, tokens, sentence_b_start, display_mode=display_mode)

# %%
sentence_a = "The cat sat on the mat"
sentence_b = "The cat lay on the rug"
show_model_view(model, tokenizer, sentence_a, sentence_b, hide_delimiter_attn=False, display_mode="light")
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-75be0113f6a94ef5937814416e9a1126" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Attention: <select id="filter"><option value="0">All</option>
# <option value="1">Sentence A -> Sentence A</option>
# <option value="2">Sentence B -> Sentence B</option>
# <option value="3">Sentence A -> Sentence B</option>
# <option value="4">Sentence B -> Sentence A</option></select>
#             </span>
#             <div id='vis'></div>
#         </div>

# %% [markdown]
# # Explore similarity

# %% [markdown]
# Consider the pooler output for two sentences and compute their cosine distance:

# %%
def pooler_similarity(sentence_a, sentence_b):
    tokens_a = tokenizer.encode_plus(sentence_a, return_tensors='pt', add_special_tokens=True)
    tokens_b = tokenizer.encode_plus(sentence_b, return_tensors='pt', add_special_tokens=True)
    outputs_a = model(**tokens_a)
    outputs_b = model(**tokens_b)
    return torch.cosine_similarity(outputs_a.pooler_output[0], outputs_b.pooler_output[0], dim=0)

# %%
pooler_similarity(sentence_a, sentence_b)
# Out:
# tensor(0.9177, grad_fn=<DivBackward0>)

# %%
pooler_similarity(sentence_a, sentence_a)
# Out:
# tensor(1., grad_fn=<DivBackward0>)

# %%
pooler_similarity("Who is Boris Johnson?", "The British prime minister.")
# Out:
# tensor(0.9899, grad_fn=<DivBackward0>)

# %%
pooler_similarity("Who is Boris Johnson?", "I don't know")
# Out:
# tensor(0.5651, grad_fn=<DivBackward0>)

# %% [markdown]
# However adding a period:

# %%
pooler_similarity("Who is Boris Johnson?", "I don't know.")
# Out:
# tensor(0.9862, grad_fn=<DivBackward0>)
