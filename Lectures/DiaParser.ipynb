# %% [markdown]
# # DiaParser
# **Direct Attentive Dependency Parser**

# %%
# !pip install diaparser

# %%
from diaparser.parsers import Parser
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# ### Create a parser for Italian

# %% [markdown]
# Load a pretrained model for Italian, named `it_isdt.dbmdz-xxl`, i.e. a parser trained on the Italian ISDT treebank, using the transformner model `dbmdz/bert-base-italian-xxl-cased`.
#
# The model will be downloaded and cached locally for further use.

# %%
parser = Parser.load('it_isdt.dbmdz-electra-xxl')
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Some weights of the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Using bos_token, but it is not set yet.
# Using eos_token, but it is not set yet.

# %% [markdown]
# Alternatively, we can just specify the language and accept a default model:

# %%
parser = Parser.load(lang='it')
# Out:
# Some weights of the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Using bos_token, but it is not set yet.
# Using eos_token, but it is not set yet.

# %% [markdown]
# You may parse plain text, by telling the language used:

# %%
dataset = parser.predict('Lo schermo è buono, ma la batteria dura poco.', text='it')

# %% [markdown]
# `dataset` is an instance of `diaparser.utils.Dataset` containing the parse trees for each sentence.
#
# Let's look at the first one:

# %%
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = Lo schermo è buono, ma la batteria dura poco.
# 1	Lo	_	_	_	_	2	det	_	_
# 2	schermo	_	_	_	_	4	nsubj	_	_
# 3	è	_	_	_	_	4	cop	_	_
# 4	buono	_	_	_	_	0	root	_	_
# 5	,	_	_	_	_	9	punct	_	_
# 6	ma	_	_	_	_	9	cc	_	_
# 7	la	_	_	_	_	8	det	_	_
# 8	batteria	_	_	_	_	9	nsubj	_	_
# 9	dura	_	_	_	_	4	conj	_	_
# 10	poco	_	_	_	_	9	advmod	_	_
# 11	.	_	_	_	_	4	punct	_	_

# %% [markdown]
# ## Display parse tree

# %%
from spacy import displacy

def display(sent):
    displacy.render(sent.to_displacy(), style='dep', manual=True,
                    options={'compact': True, 'distance': 120, 
                             'word_spacing': 20, 'offset_x':20})

# %%
display(dataset.sentences[0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="150f3e7b80cf4253b91e6b45c4b4b694-0" class="displacy" width="1460" height="422.0" direction="ltr" style="max-width: none; height: 422.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="20">ROOT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="20"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Lo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">schermo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">è</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">buono</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="620">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="740">ma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="740"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="980">batteria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="980"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">dura</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">poco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="1340">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1340"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-0" stroke-width="2px" d="M152,362.0 152,342.0 245.0,342.0 245.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M152,364.0 L148,356.0 156,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-1" stroke-width="2px" d="M272,362.0 272,322.0 488.0,322.0 488.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M272,364.0 L268,356.0 276,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-2" stroke-width="2px" d="M392,362.0 392,342.0 485.0,342.0 485.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M392,364.0 L388,356.0 396,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-3" stroke-width="2px" d="M32,362.0 32,282.0 494.0,282.0 494.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">root</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M494.0,364.0 L498.0,356.0 490.0,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-4" stroke-width="2px" d="M632,362.0 632,282.0 1094.0,282.0 1094.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M632,364.0 L628,356.0 636,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-5" stroke-width="2px" d="M752,362.0 752,302.0 1091.0,302.0 1091.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M752,364.0 L748,356.0 756,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-6" stroke-width="2px" d="M872,362.0 872,342.0 965.0,342.0 965.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M872,364.0 L868,356.0 876,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-7" stroke-width="2px" d="M992,362.0 992,342.0 1085.0,342.0 1085.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M992,364.0 L988,356.0 996,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-150f3e7b80cf4253b91e6b45c4b4b694-0-8" stroke-width="2px" d="M512,

# %%
morph = parser.predict('Non darmelo, prendilo tu', text='it')
morph.sentences[0]
# Out:
# # sent_id = 1
# # text = Non darmelo, prendilo tu
# 1	Non	_	_	_	_	2	advmod	_	_
# 2-4	darmelo	_	_	_	_	_	_	_	_
# 2	dar	_	_	_	_	0	root	_	_
# 3	me	_	_	_	_	2	iobj	_	_
# 4	lo	_	_	_	_	2	obj	_	_
# 5	,	_	_	_	_	2	punct	_	_
# 6-7	prendilo	_	_	_	_	_	_	_	_
# 6	prendi	_	_	_	_	2	conj	_	_
# 7	lo	_	_	_	_	6	obj	_	_
# 8	tu	_	_	_	_	6	nsubj	_	_

# %% [markdown]
# ## English
# Load a pretrained model for English, named `en_ewt.electra-base`, i.e. a parser trained on the English EWT treebank, using the transformner model `electra-base-disciminator`.

# %%
parser_en = Parser.load('en_ewt.electra-base')
# Out:
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/electra-base-discriminator were not used when initializing ElectraModel: ['discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.weight']
# - This IS expected if you are initializing ElectraModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Using bos_token, but it is not set yet.
# Using eos_token, but it is not set yet.

# %% [markdown]
# You may parse plain text, by telling the language used:

# %%
dataset = parser_en.predict('I like the display, but the battery life is short.', text='en')

# %% [markdown]
# `dataset` is an instance of `diaparser.utils.Dataset` containing the predicted syntactic trees.
#
# Let's look at the first one:

# %%
dataset.sentences[0]
# Out:
# # sent_id = 1
# # text = I like the display, but the battery life is short.
# 1	I	_	_	_	_	2	nsubj	_	_
# 2	like	_	_	_	_	0	root	_	_
# 3	the	_	_	_	_	4	det	_	_
# 4	display	_	_	_	_	2	obj	_	_
# 5	,	_	_	_	_	11	punct	_	_
# 6	but	_	_	_	_	11	cc	_	_
# 7	the	_	_	_	_	9	det	_	_
# 8	battery	_	_	_	_	9	compound	_	_
# 9	life	_	_	_	_	11	nsubj	_	_
# 10	is	_	_	_	_	11	cop	_	_
# 11	short	_	_	_	_	2	conj	_	_
# 12	.	_	_	_	_	2	punct	_	_

# %%
display(dataset.sentences[0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9724b7b717f24d3f885e4443115a9946-0" class="displacy" width="1580" height="422.0" direction="ltr" style="max-width: none; height: 422.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="20">ROOT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="20"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">display</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="620">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="740">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="740"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="980">battery</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="980"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">life</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="1340">short</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1340"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="382.0">
#     <tspan class="displacy-word" fill="currentColor" x="1460">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1460"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-0" stroke-width="2px" d="M152,362.0 152,342.0 245.0,342.0 245.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M152,364.0 L148,356.0 156,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-1" stroke-width="2px" d="M32,362.0 32,322.0 248.0,322.0 248.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">root</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M248.0,364.0 L252.0,356.0 244.0,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-2" stroke-width="2px" d="M392,362.0 392,342.0 485.0,342.0 485.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M392,364.0 L388,356.0 396,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-3" stroke-width="2px" d="M272,362.0 272,322.0 488.0,322.0 488.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M488.0,364.0 L492.0,356.0 484.0,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-4" stroke-width="2px" d="M632,362.0 632,282.0 1334.0,282.0 1334.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M632,364.0 L628,356.0 636,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-5" stroke-width="2px" d="M752,362.0 752,302.0 1331.0,302.0 1331.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M752,364.0 L748,356.0 756,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-6" stroke-width="2px" d="M872,362.0 872,322.0 1088.0,322.0 1088.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M872,364.0 L868,356.0 876,356.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9724b7b717f24d3f885e4443115a9946-0-7" stroke-width="2px" d="M992,362.0 992,342.0 1085.0,342.0 1085.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9724b7b717f24d3f885e4443115a9946-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</t

# %% [markdown]
# ## Parse from tokenized text

# %% [markdown]
# Or you can provide tokenized text, as weel ask to see the estimated probabiity for each predicted arc:

# %%
dataset = parser_en.predict(['I', 'liked', 'the', 'display', '.'], prob=True)

# %% [markdown]
# You may then look at individual fields of the tokens in a sentence and the probability of their arcs.

# %%
import torch
print(f"arcs:  {dataset.arcs[0]}\n"
      f"rels:  {dataset.rels[0]}\n"
      f"probs: {dataset.probs[0].gather(1,torch.tensor(dataset.arcs[0]).unsqueeze(1)).squeeze(-1)}")
# Out:
# arcs:  [2, 0, 4, 2, 2]
# rels:  ['nsubj', 'root', 'det', 'obj', 'punct']
# probs: tensor([1.0000, 1.0000, 1.0000, 1.0000, 0.9999])

# %%
# Fancy way of doing:
[float(dataset.probs[0][i,j]) for i,j in enumerate(dataset.arcs[0])]
# Out:
# [1.0, 1.0, 0.9999973773956299, 0.9999995231628418, 0.9998992681503296]

# %% [markdown]
# # Information Extraction

# %% [markdown]
# From tha AODA act of Ontario: https://www.aoda.ca/integrated/#etrame

# %%
art16 = """In addition to the requirements under section 7, obligated organizations that are school boards
or educational or training institutions shall provide educators with accessibility awareness training
related to accessible program or course delivery and instruction.
Obligated organizations that are school boards or educational or training institutions shall keep
a record of the training provided under this section, including the dates on which the training
is provided and the number of individuals to whom it is provided."""

# %%
output = parser_en.predict(art16, text='en')

# %%
output.sentences
# Out:
# [# sent_id = 1
#  # text = In addition to the requirements under section 7, obligated organizations that are school boards or educational or training institutions shall provide educators with accessibility awareness training related to accessible program or course delivery and instruction.
#  1	In	_	_	_	_	2	case	_	_
#  2	addition	_	_	_	_	22	obl	_	_
#  3	to	_	_	_	_	5	case	_	_
#  4	the	_	_	_	_	5	det	_	_
#  5	requirements	_	_	_	_	2	nmod	_	_
#  6	under	_	_	_	_	7	case	_	_
#  7	section	_	_	_	_	5	nmod	_	_
#  8	7	_	_	_	_	7	nummod	_	_
#  9	,	_	_	_	_	22	punct	_	_
#  10	obligated	_	_	_	_	11	amod	_	_
#  11	organizations	_	_	_	_	22	nsubj	_	_
#  12	that	_	_	_	_	15	nsubj	_	_
#  13	are	_	_	_	_	15	cop	_	_
#  14	school	_	_	_	_	15	compound	_	_
#  15	boards	_	_	_	_	11	acl:relcl	_	_
#  16	or	_	_	_	_	20	cc	_	_
#  17	educational	_	_	_	_	20	amod	_	_
#  18	or	_	_	_	_	19	cc	_	_
#  19	training	_	_	_	_	17	conj	_	_
#  20	institutions	_	_	_	_	15	conj	_	_
#  21	shall	_	_	_	_	22	aux	_	_
#  22	provide	_	_	_	_	0	root	_	_
#  23	educators	_	_	_	_	22	obj	_	_
#  24	with	_	_	_	_	27	case	_	_
#  25	accessibility	_	_	_	_	26	compound	_	_
#  26	awareness	_	_	_	_	27	compound	_	_
#  27	training	_	_	_	_	22	obl	_	_
#  28	related	_	_	_	_	27	amod	_	_
#  29	to	_	_	_	_	34	case	_	_
#  30	accessible	_	_	_	_	34	amod	_	_
#  31	program	_	_	_	_	34	compound	_	_
#  32	or	_	_	_	_	33	cc	_	_
#  33	course	_	_	_	_	31	conj	_	_
#  34	delivery	_	_	_	_	28	obl	_	_
#  35	and	_	_	_	_	36	cc	_	_
#  36	instruction	_	_	_	_	31	conj	_	_
#  37	.	_	_	_	_	22	punct	_	_,
#  # sent_id = 2
#  # text = Obligated organizations that are school boards or educational or training institutions shall keep a record of the training provided under this section, including the dates on which the training is provided and the number of individuals to whom it is provided.
#  1	Obligated	_	_	_	_	2	amod	_	_
#  2	organizations	_	_	_	_	13	nsubj	_	_
#  3	that	_	_	_	_	6	nsubj	_	_
#  4	are	_	_	_	_	6	cop	_	_
#  5	school	_	_	_	_	6	compound	_	_
#  6	boards	_	_	_	_	2	acl:relcl	_	_
#  7	or	_	_	_	_	11	cc	_	_
#  8	educational	_	_	_	_	11	amod	_	_
#  9	or	_	_	_	_	10	cc	_	_
#  10	training	_	_	_	_	8	conj	_	_
#  11	institutions	_	_	_	_	6	conj	_	_
#  12	shall	_	_	_	_	13	aux	_	_
#  13	keep	_	_	_	_	0	root	_	_
#  14	a	_	_	_	_	15	det	_	_
#  15	record	_	_	_	_	13	obj	_	_
#  16	of	_	_	_	_	18	case	_	_
#  17	the	_	_	_	_	18	det	_	_
#  18	training	_	_	_	_	15	nmod	_	_
#  19	provided	_	_	_	_	18	acl	_	_
#  20	under	_	_	_	_	22	case	_	_
#  21	this	_	_	_	_	22	det	_	_
#  22	section	_	_	_	_	19	obl	_	_
#  23	,	_	_	_	_	13	punct	_	_
#  24	including	_	_	_	_	26	case	_	_
#  25	the	_	_	_	_	26	det	_	_
#  26	dates	_	_	_	_	15	nmod	_	_
#  27	on	_	_	_	_	28	case	_	_
#  28	which	_	_	_	_	32	obl	_	_
#  29	the	_	_	_	_	30	det	_	_
#  30	training	_	_	_	_	32	nsubj:pass	_	_
#  31	is	_	_	_	_	32	aux:pass	_	_
#  32	provided	_	_	_	_	26	acl:relcl	_	_
#  33	and	_	_	_	_	35	cc	_	_
#  34	the	_	_	_	_	35	det	_	_
#  35	number	_	_	_	_	26	conj	_	_
#  36	of	_	_	_	_	37	case	_	_
#  37	individuals	_	_	_	_	35	nmod	_	_
#  38	to	_	_	_	_	39	case	_	_
#  39	whom	_	_	_	_	42	obl	_	_
#  40	it	_	_	_	_	42	nsubj:pass	_	_
#  41	is	_	_	_	_	42	aux:pass	_	_
#  42	provided	_	_	_	_	37	acl:relcl	_	_
#  43	.	_	_	_	_	13	punct	_	_]

# %%
display(output.sentences[0])
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9b35f82fd99045ee969eee491e24b510-0" class="displacy" width="4580" height="722.0" direction="ltr" style="max-width: none; height: 722.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="20">ROOT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="20"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">addition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="620">requirements</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="740">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="740"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">section</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="980">7</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="980"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">obligated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1340">organizations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1340"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1460">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1460"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">school</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1820">boards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1820"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2060">educational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2060"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2180">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2180"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2420">institutions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2420"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2540">shall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2540"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">provide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2780">educators</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2780"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">accessibility</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="3140">awareness</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3140"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="3260">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3260"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="3380">related</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3380"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="682.0">
#     <tspan class="displacy-word" fill="currentColor" x="3620">accessible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3620"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentC

# %% [markdown]
# # Match a pattern

# %%
import spacy
from spacy.matcher import DependencyMatcher
# !python -m spacy download en_core_web_sm

nlp = spacy.load("en_core_web_sm")
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# 2022-03-23 09:24:15.842092: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-23 09:24:15.842141: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Requirement already satisfied: en-core-web-sm==3.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl#egg=en_core_web_sm==3.2.0 in /usr/local/lib/python3.8/dist-packages (3.2.0)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.22.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.63.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.22.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (45.2.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (20.9)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.7)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.4)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
def visualise_subtrees(doc, subtrees):

    words = [{"text": t.text, "tag": t.pos_} for t in doc]

    if not isinstance(subtrees[0], list):
        subtrees = [subtrees]

    for subtree in subtrees:
        arcs = []
        tree_indices = set(subtree)
        for index in subtree:
            token = doc[index]
            head = token.head
            if token.head.i == token.i or token.head.i not in tree_indices:
                continue
            else:
                if token.i < head.i:
                    arcs.append(
                        {
                            "start": token.i,
                            "end": head.i,
                            "label": token.dep_,
                            "dir": "left",
                        }
                    )
                else:
                    arcs.append(
                        {
                            "start": head.i,
                            "end": token.i,
                            "label": token.dep_,
                            "dir": "right",
                        }
                    )
        print("Subtree: ", subtree)
        displacy.render(
            {"words": words, "arcs": arcs},
            style="dep",
            options={'compact': True, "distance": 120},
            manual=True
        )

# %% [markdown]
# ### Pattern for a subtree
#
# - rooted at a VERB (`keep`)
# - with a MODAL auxiliary (`shall`)
# - with a SUBJECT (`nsubj`)
# - and an OBJECT (`dobj`)

# %%
pattern = [{'RIGHT_ID': 'root',
            'RIGHT_ATTRS': {'ORTH': 'keep'}},
           {'LEFT_ID': 'root', 'REL_OP': '>', 'RIGHT_ID': 'MODAL',
             'RIGHT_ATTRS': {'ORTH': 'shall'}},
           {'LEFT_ID': 'root', 'REL_OP': '>', 'RIGHT_ID': 'SUBJ',
             'RIGHT_ATTRS': {'DEP': 'nsubj'}},
           {'LEFT_ID': 'root', 'REL_OP': '>', 'RIGHT_ID': 'OBJ',
            'RIGHT_ATTRS': {'DEP': 'dobj'}}]

# %%
matcher = DependencyMatcher(nlp.vocab)
matcher.add("pattern", [pattern])

# %% [markdown]
# Apply to second sentence from Art. 16

# %%
art16_2 = nlp("""Obligated organizations that are school boards or educational or training institutions shall keep a record of the training provided under this section, including the dates on which the training
is provided and the number of individuals to whom it is provided.""")

# %% [markdown]
# Show the parse tree

# %%
displacy.render(art16_2, options={'compact': True, 'distance': 120, 
                             'word_spacing': 20, 'offset_x':20})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="81c762dd821345a991bf165320389fc0-0" class="displacy" width="5060" height="602.0" direction="ltr" style="max-width: none; height: 602.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="20">Obligated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="20">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">organizations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="260">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">school</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="620">boards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="620">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="740">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="740">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">educational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="980">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="980">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">institutions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1340">shall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1340">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1460">keep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1460">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">record</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1820">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1820">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2060">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2060">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2180">provided</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2180">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2420">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2420">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2540">section,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2540">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">including</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2780">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2780">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">dates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="3140">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3140">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="3260">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3260">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="3380">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="562.0">
#     <tspan class="displacy-word" fill="currentColor" x="3620">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill=

# %% [markdown]
# Extract and visualize the subtree

# %%
match = matcher(art16_2)[0]
subtree = match[1]
visualise_subtrees(art16_2, subtree)
# Out:
# Subtree:  [12, 11, 1, 14]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9895025cc6ce4da8b8812bf449053faf-0" class="displacy" width="5330" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Obligated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">organizations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">school</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">boards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">educational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">institutions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">shall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">keep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">record</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">provided</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">section</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">including</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">dates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill=

# %% [markdown]
# Notice that the words that are in the requested relaztion are quite far apart and hence shallow analysis will not be bale to highlit them.
